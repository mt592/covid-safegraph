# %%
import boto3
import awscli

# %%
session = boto3.session.Session(
    aws_access_key_id = 'AKIAWWZ7POZOI2HE24P3',
    aws_secret_access_key = '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',
    region_name = 'us-west-2')

# %%
s3 = session.client('s3')

# %%
s3.list_objects(Bucket = 'sg-c19-response', Prefix = 'weekly-patterns')
# Out:
# {'ResponseMetadata': {'RequestId': '027D5ADA8C17FCBE',
#   'HostId': 'Fpas6YrKMIF576YbfUOvSg+JvfLA0UwCyvbFUurLUrxpU4qDWD3HHWX3A7L3F5s+T3H03pcL//Y=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'Fpas6YrKMIF576YbfUOvSg+JvfLA0UwCyvbFUurLUrxpU4qDWD3HHWX3A7L3F5s+T3H03pcL//Y=',
#    'x-amz-request-id': '027D5ADA8C17FCBE',
#    'date': 'Wed, 10 Jun 2020 15:23:00 GMT',
#    'x-amz-bucket-region': 'us-west-2',
#    'content-type': 'application/xml',
#    'transfer-encoding': 'chunked',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'IsTruncated': False,
#  'Marker': '',
#  'Contents': [{'Key': 'weekly-patterns/v1/home_summary_file/2020-03-01-home-panel-summary.csv',
#    'LastModified': datetime.datetime(2020, 3, 26, 20, 58, 15, tzinfo=tzutc()),
#    'ETag': '"7a70ee905e0bb034564930de933ebefe-2"',
#    'Size': 15714056,
#    'StorageClass': 'STANDARD'},
#   {'Key': 'weekly-patterns/v1/home_summary_file/2020-03-08-home-panel-summary.csv',
# ...

# %%
# !aws s3 ls s3://sg-c19-response/
# Out:
# Unable to locate credentials. You can configure credentials by running "aws configure".

# %%
import boto3

# %%
session = boto3.session.Session(
    aws_access_key_id = 'AKIAWWZ7POZOI2HE24P3',
    aws_secret_access_key = '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',
    region_name = 'us-west-2')

# %%
bucket = s3.Bucket('sg-c19-response')
for file in bucket.objects.all():
    print(file.key)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-76656118bbc7> in <module>
# ----> 1 bucket = s3.Bucket('sg-c19-response')
#       2 for file in bucket.objects.all():
#       3     print(file.key)
#
# ~/anaconda3/lib/python3.7/site-packages/botocore/client.py in __getattr__(self, item)
#     564         raise AttributeError(
#     565             "'%s' object has no attribute '%s'" % (
# --> 566                 self.__class__.__name__, item)
#     567         )
#     568
#
# AttributeError: 'S3' object has no attribute 'Bucket'
